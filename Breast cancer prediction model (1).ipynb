# %% [markdown]
# TASK 4: BREAST CANCER DETECTION USING MACHINE LEARRNING WHETHER IT IS BENIGN OR MALIGNANT

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
import numpy as np

# %%
bc_data = pd.read_csv('C:/Users/91843/data.csv')

# %%
bc_data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
bc_data = bc_data.drop(columns="Unnamed: 32", axis=1)

# %%
bc_data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
bc_data["diagnosis"]=bc_data["diagnosis"].map({"M":1,"B":0})
#M=Malignant tumor=1
#B=Beningn tumor=0

# %%
bc_data.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
#checking any null values re present
bc_data.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
bc_data.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
mean_features=list(bc_data.columns[2:12])
standarderror_features=list(bc_data.columns[12:22])
worst_features=list(bc_data.columns[22:32])

# %%
mean_features
# Out:
# ['radius_mean',
#  'texture_mean',
#  'perimeter_mean',
#  'area_mean',
#  'smoothness_mean',
#  'compactness_mean',
#  'concavity_mean',
#  'concave points_mean',
#  'symmetry_mean',
#  'fractal_dimension_mean']

# %%
standarderror_features
# Out:
# ['radius_se',
#  'texture_se',
#  'perimeter_se',
#  'area_se',
#  'smoothness_se',
#  'compactness_se',
#  'concavity_se',
#  'concave points_se',
#  'symmetry_se',
#  'fractal_dimension_se']

# %%
worst_features
# Out:
# ['radius_worst',
#  'texture_worst',
#  'perimeter_worst',
#  'area_worst',
#  'smoothness_worst',
#  'compactness_worst',
#  'concavity_worst',
#  'concave points_worst',
#  'symmetry_worst',
#  'fractal_dimension_worst']

# %%
mean_features.append('diagnosis')
standarderror_features.append('diagnosis')
worst_features.append('diagnosis')

# %%
corr=bc_data[mean_features].corr()

# %%
corr
# Out:
#                         radius_mean  texture_mean  perimeter_mean  area_mean  \
# radius_mean                1.000000      0.323782        0.997855   0.987357
# texture_mean               0.323782      1.000000        0.329533   0.321086
# perimeter_mean             0.997855      0.329533        1.000000   0.986507
# area_mean                  0.987357      0.321086        0.986507   1.000000
# smoothness_mean            0.170581     -0.023389        0.207278   0.177028
# compactness_mean           0.506124      0.236702        0.556936   0.498502
# concavity_mean             0.676764      0.302418        0.716136   0.685983
# concave points_mean        0.822529      0.293464        0.850977   0.823269
# symmetry_mean              0.147741      0.071401        0.183027   0.151293
# fractal_dimension_mean    -0.311631     -0.076437       -0.261477  -0.283110
# diagnosis                  0.730029      0.415185        0.742636   0.708984
#
# ...

# %%
corr=bc_data[standarderror_features].corr()

# %%
corr
# Out:
#                       radius_se  texture_se  perimeter_se   area_se  \
# radius_se              1.000000    0.213247      0.972794  0.951830
# texture_se             0.213247    1.000000      0.223171  0.111567
# perimeter_se           0.972794    0.223171      1.000000  0.937655
# area_se                0.951830    0.111567      0.937655  1.000000
# smoothness_se          0.164514    0.397243      0.151075  0.075150
# compactness_se         0.356065    0.231700      0.416322  0.284840
# concavity_se           0.332358    0.194998      0.362482  0.270895
# concave points_se      0.513346    0.230283      0.556264  0.415730
# symmetry_se            0.240567    0.411621      0.266487  0.134109
# fractal_dimension_se   0.227754    0.279723      0.244143  0.127071
# diagnosis              0.567134   -0.008303      0.556141  0.548236
#
#                       smoothness_se  compactness_se  concavity_se  \
# radius_se                  0.164514        0.356065      0.332358
# ...

# %%
corr=bc_data[worst_features].corr()
corr
# Out:
#                          radius_worst  texture_worst  perimeter_worst  \
# radius_worst                 1.000000       0.359921         0.993708
# texture_worst                0.359921       1.000000         0.365098
# perimeter_worst              0.993708       0.365098         1.000000
# area_worst                   0.984015       0.345842         0.977578
# smoothness_worst             0.216574       0.225429         0.236775
# compactness_worst            0.475820       0.360832         0.529408
# concavity_worst              0.573975       0.368366         0.618344
# concave points_worst         0.787424       0.359755         0.816322
# symmetry_worst               0.243529       0.233027         0.269493
# fractal_dimension_worst      0.093492       0.219122         0.138957
# diagnosis                    0.776454       0.456903         0.782914
#
#                          area_worst  smoothness_worst  compactness_worst  \
# ...

# %% [markdown]
# DATA VISUALIZATION:

# %%
import matplotlib.pyplot as plt

sns.set(style="whitegrid")
plt.figure(figsize=(7, 4))
sns.countplot(x='diagnosis', data=bc_data)
plt.title('Distribution of Diagnosis')
plt.show()

# %%
# Visualize pair-wise relationships between selected features
features_subset = ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'diagnosis']
sns.pairplot(bc_data[features_subset], hue='diagnosis', palette='viridis')
plt.suptitle('Pair-wise Relationships between Features', y=1.02)
plt.show()

# %%
correlation_matrix = bc_data[features_subset].corr()
plt.figure(figsize=(7, 7))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix')
plt.show()

# %%
selected_features = ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean']
plt.figure(figsize=(6, 4))
for feature in selected_features:
    sns.violinplot(x='diagnosis', y=feature, data=bc_data)
    plt.title(f'Violin Plot of {feature} by Diagnosis')
    plt.show()

# %% [markdown]
# TRAINING THE MODEL:

# %%
prediction_vars=['radius_mean', 'perimeter_mean', 'area_mean', 'compactness_mean', 'concavity_mean',
                 'concave points_mean', 'radius_se', 'area_se',  'radius_worst',
                 'perimeter_worst', 'compactness_worst']

# %%
from sklearn.model_selection import train_test_split

# %%
train, test=train_test_split(bc_data, test_size=0.15, random_state=1)

# %%
train_x=train[prediction_vars]
train_y=train["diagnosis"]
test_x=test[prediction_vars]
test_y=test["diagnosis"]

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
model= RandomForestClassifier()

# %%
model.fit(test_x, test_y)
# Out:
# RandomForestClassifier()

# %%
predictions= model.predict(test_x)

# %%
test_y
# Out:
# 421    0
# 47     1
# 292    0
# 186    1
# 414    1
#       ..
# 335    1
# 308    0
# 370    1
# 403    0
# 120    0
# Name: diagnosis, Length: 86, dtype: int64

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(test_y, predictions)
# Out:
# array([[52,  0],
#        [ 0, 34]], dtype=int64)

# %%
print(test_y.value_counts())
# Out:
# diagnosis
# 0    52
# 1    34
# Name: count, dtype: int64

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score

# %%
precision=precision_score(test_y, predictions)
print("The precision is:", precision)

recall=recall_score(test_y, predictions)
print("The recall is:", recall)

accuracy=accuracy_score(test_y, predictions)
print("The accuracy is:", accuracy)
# Out:
# The precision is: 1.0
# The recall is: 1.0
# The accuracy is: 1.0

# %%
from sklearn.metrics import classification_report
print(classification_report(test_y, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        52
#            1       1.00      1.00      1.00        34
#
#     accuracy                           1.00        86
#    macro avg       1.00      1.00      1.00        86
# weighted avg       1.00      1.00      1.00        86

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

mae = mean_absolute_error(test_y, predictions)
print("Mean Absolute Error (MAE):", mae)

rmse = mean_squared_error(test_y, predictions, squared=False)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Mean Absolute Error (MAE): 0.0
# Root Mean Squared Error (RMSE): 0.0

# %%
input_data = np.array([10.0, 15.0, 100.0, 0.1, 0.15, 0.05, 0.02, 0.015, 0.2, 0.1, 120.0])
input_data_reshaped = input_data.reshape(1, -1)

# Make predictions for the new data point
new_data_prediction = model.predict(input_data_reshaped)

# Print the prediction
if new_data_prediction[0] == 0:
    print('The tumor is Malignant')
else:
    print('The tumor is Benign')
# Out:
# The tumor is Malignant
# C:\Users\91843\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
